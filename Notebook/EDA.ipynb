# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
harvestshrimp = pd.read_csv('E:\JalaTech\Data\measurements.csv')
harvestshrimp.head()
# Out:
#    pond_id  cycle_id measured_date  morning_temperature  evening_temperature  \
# 0    31250     15009    2022-04-16               29.000                  NaN
# 1    21226     10897    2021-07-30                  NaN                  NaN
# 2    45694     27893    2023-12-07               29.342               32.445
# 3    34732     17637    2022-08-11               24.900               25.900
# 4        8     19874    2023-04-04               28.211               30.869
#
#    morning_do  evening_do  morning_salinity  evening_salinity  morning_pH  \
# 0         NaN         NaN            28.000               NaN       8.100
# 1         NaN         NaN               NaN               NaN         NaN
# 2       4.355       6.253             2.155             2.686       8.294
# 3       5.100       3.800            21.000               NaN       7.400
# 4       3.106       4.370            12.673            12.041       7.911
#
# ...

# %%
plt.figure(figsize=(2,2), dpi= 80)
sns.pairplot(harvestshrimp, kind="scatter", hue="morning_temperature", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 plt.figure(figsize=(2,2), dpi= 80)
# ----> 2 sns.pairplot(harvestshrimp, kind="scatter", hue="morning_temperature", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
#       3 plt.show()
#
# File e:\JalaTech\venv\lib\site-packages\seaborn\axisgrid.py:2153, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2151     diag_kws.setdefault("fill", True)
#    2152     diag_kws.setdefault("warn_singular", False)
# -> 2153     grid.map_diag(kdeplot, **diag_kws)
#    2155 # Maybe plot on the off-diagonals
#    2156 if diag_kind is not None:
#
# File e:\JalaTech\venv\lib\site-packages\seaborn\axisgrid.py:1513, in PairGrid.map_diag(self, func, **kwargs)
# ...

# %%
harvestshrimp.boxplot()
# Out:
# <Axes: >
